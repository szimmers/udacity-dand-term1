# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

% matplotlib inline

# %%
df = pd.read_csv('source_data/csv/sugar_consumption.csv')

# %%
df.head()
# Out:
#               Unnamed: 0   1961   1962   1963   1964   1965   1966   1967  \
# 0               Abkhazia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1            Afghanistan    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2  Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3                Albania  30.14  30.14  32.88  35.62  35.62  35.62  38.36
# 4                Algeria  46.58  49.32  46.58  49.32  46.58  46.58  49.32
#
#     1968   1969     ...        1996   1997   1998   1999   2000   2001   2002  \
# 0    NaN    NaN     ...         NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1    NaN    NaN     ...         NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2    NaN    NaN     ...         NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3  38.36  38.36     ...       68.49  60.27  60.27  57.53  65.75  68.49  71.23
# 4  49.32  46.58     ...       73.97  79.45  54.80  60.27  82.19  79.45  82.19
#
#     2003   2004  Unnamed: 45
# 0    NaN    NaN          NaN
# 1    NaN    NaN          NaN
# 2    NaN    NaN          NaN
# 3  65.75  65.75          NaN
# 4  84.93  84.93          NaN
#
# [5 rows x 46 columns]

# %%
# replace spaces with underscores and make lowercase
df.rename(columns=lambda x: x.strip().lower().replace(" ", "_"), inplace=True)

# %%
df.head()
# Out:
#               unnamed:_0   1961   1962   1963   1964   1965   1966   1967  \
# 0               Abkhazia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1            Afghanistan    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2  Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3                Albania  30.14  30.14  32.88  35.62  35.62  35.62  38.36
# 4                Algeria  46.58  49.32  46.58  49.32  46.58  46.58  49.32
#
#     1968   1969     ...        1996   1997   1998   1999   2000   2001   2002  \
# 0    NaN    NaN     ...         NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1    NaN    NaN     ...         NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2    NaN    NaN     ...         NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3  38.36  38.36     ...       68.49  60.27  60.27  57.53  65.75  68.49  71.23
# 4  49.32  46.58     ...       73.97  79.45  54.80  60.27  82.19  79.45  82.19
#
#     2003   2004  unnamed:_45
# 0    NaN    NaN          NaN
# 1    NaN    NaN          NaN
# 2    NaN    NaN          NaN
# 3  65.75  65.75          NaN
# 4  84.93  84.93          NaN
#
# [5 rows x 46 columns]

# %%
# rename country column in place
df.rename(columns={'unnamed:_0': 'country'}, inplace=True)
df.head()
# Out:
#                  country   1961   1962   1963   1964   1965   1966   1967  \
# 0               Abkhazia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1            Afghanistan    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2  Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3                Albania  30.14  30.14  32.88  35.62  35.62  35.62  38.36
# 4                Algeria  46.58  49.32  46.58  49.32  46.58  46.58  49.32
#
#     1968   1969     ...        1996   1997   1998   1999   2000   2001   2002  \
# 0    NaN    NaN     ...         NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1    NaN    NaN     ...         NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2    NaN    NaN     ...         NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3  38.36  38.36     ...       68.49  60.27  60.27  57.53  65.75  68.49  71.23
# 4  49.32  46.58     ...       73.97  79.45  54.80  60.27  82.19  79.45  82.19
#
#     2003   2004  unnamed:_45
# 0    NaN    NaN          NaN
# 1    NaN    NaN          NaN
# 2    NaN    NaN          NaN
# 3  65.75  65.75          NaN
# 4  84.93  84.93          NaN
#
# [5 rows x 46 columns]

# %%
# pull out just the Canada data
dfc = df.loc[df['country'] == 'Canada']

# %%
dfc.head()
# Out:
#    country    1961    1962    1963    1964    1965    1966    1967    1968  \
# 37  Canada  123.29  128.77  126.03  123.29  126.03  134.25  128.77  128.77
#
#       1969     ...         1996    1997    1998    1999    2000    2001  \
# 37  134.25     ...       134.25  139.73  142.47  139.73  145.21  153.43
#
#       2002   2003   2004  unnamed:_45
# 37  167.12  172.6  172.6          NaN
#
# [1 rows x 46 columns]

# %%
# drop country column
cols = [0]
dfc.drop(dfc.columns[cols], axis=1, inplace=True)
dfc.head()
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
#       1961    1962    1963    1964    1965    1966    1967    1968    1969  \
# 37  123.29  128.77  126.03  123.29  126.03  134.25  128.77  128.77  134.25
#
#       1970     ...         1996    1997    1998    1999    2000    2001  \
# 37  131.51     ...       134.25  139.73  142.47  139.73  145.21  153.43
#
#       2002   2003   2004  unnamed:_45
# 37  167.12  172.6  172.6          NaN
#
# [1 rows x 45 columns]

# %%
# transpose it
dfc = dfc.T
dfc.head()
# Out:
#           37
# 1961  123.29
# 1962  128.77
# 1963  126.03
# 1964  123.29
# 1965  126.03

# %%
# rename the columns
dfc.index.name = 'year'
dfc.columns = ['value']
dfc.head()
# Out:
#        value
# year
# 1961  123.29
# 1962  128.77
# 1963  126.03
# 1964  123.29
# 1965  126.03

# %%
# drop if any value in the row has a nan
dfc.dropna(how='any', inplace = True);

# %%
# for plotting ease, make the year a column
dfc.reset_index(inplace = True)
dfc.head()
# Out:
#    year   value
# 0  1961  123.29
# 1  1962  128.77
# 2  1963  126.03
# 3  1964  123.29
# 4  1965  126.03

# %%
dfc.plot();

# %%
plt.plot(dfc['year'], dfc['value'])

plt.title('Sugar consumption per person, Canada')
plt.xlabel('Year')
plt.ylabel('g per day')

plt.show()
