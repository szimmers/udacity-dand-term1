# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

% matplotlib inline

# %%
df = pd.read_csv('source_data/csv/electricity_consumption.csv')

# %%
df.head()
# Out:
#   Electricity consumption, per capita (kWh)  1960  1961  1962  1963  1964  \
# 0                                  Abkhazia   NaN   NaN   NaN   NaN   NaN
# 1                               Afghanistan   NaN   NaN   NaN   NaN   NaN
# 2                     Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN
# 3                                   Albania   NaN   NaN   NaN   NaN   NaN
# 4                                   Algeria   NaN   NaN   NaN   NaN   NaN
#
#    1965  1966  1967  1968     ...              2002         2003         2004  \
# 0   NaN   NaN   NaN   NaN     ...               NaN          NaN          NaN
# 1   NaN   NaN   NaN   NaN     ...               NaN          NaN          NaN
# 2   NaN   NaN   NaN   NaN     ...               NaN          NaN          NaN
# 3   NaN   NaN   NaN   NaN     ...       1459.433092  1378.656751  1691.749604
# 4   NaN   NaN   NaN   NaN     ...        714.702866   768.798600   785.622933
#
#           2005         2006         2007         2008         2009  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3  1622.587317  1146.694855  1137.949266  1510.482138  1706.976899
# 4   869.352620   840.780713   870.586163   920.914005   841.320010
#
#           2010         2011
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3  1800.870627  2021.634918
# 4   986.865004  1090.565936
#
# [5 rows x 53 columns]

# %%
# replace spaces with underscores and make lowercase
df.rename(columns=lambda x: x.strip().lower().replace(" ", "_"), inplace=True)

# %%
df.head()
# Out:
#   electricity_consumption,_per_capita_(kwh)  1960  1961  1962  1963  1964  \
# 0                                  Abkhazia   NaN   NaN   NaN   NaN   NaN
# 1                               Afghanistan   NaN   NaN   NaN   NaN   NaN
# 2                     Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN
# 3                                   Albania   NaN   NaN   NaN   NaN   NaN
# 4                                   Algeria   NaN   NaN   NaN   NaN   NaN
#
#    1965  1966  1967  1968     ...              2002         2003         2004  \
# 0   NaN   NaN   NaN   NaN     ...               NaN          NaN          NaN
# 1   NaN   NaN   NaN   NaN     ...               NaN          NaN          NaN
# 2   NaN   NaN   NaN   NaN     ...               NaN          NaN          NaN
# 3   NaN   NaN   NaN   NaN     ...       1459.433092  1378.656751  1691.749604
# 4   NaN   NaN   NaN   NaN     ...        714.702866   768.798600   785.622933
#
#           2005         2006         2007         2008         2009  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3  1622.587317  1146.694855  1137.949266  1510.482138  1706.976899
# 4   869.352620   840.780713   870.586163   920.914005   841.320010
#
#           2010         2011
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3  1800.870627  2021.634918
# 4   986.865004  1090.565936
#
# [5 rows x 53 columns]

# %%
# rename country column in place
df.rename(columns={'electricity_consumption,_per_capita_(kwh)': 'country'}, inplace=True)
df.head()
# Out:
#                  country  1960  1961  1962  1963  1964  1965  1966  1967  \
# 0               Abkhazia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1            Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3                Albania   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4                Algeria   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    1968     ...              2002         2003         2004         2005  \
# 0   NaN     ...               NaN          NaN          NaN          NaN
# 1   NaN     ...               NaN          NaN          NaN          NaN
# 2   NaN     ...               NaN          NaN          NaN          NaN
# 3   NaN     ...       1459.433092  1378.656751  1691.749604  1622.587317
# 4   NaN     ...        714.702866   768.798600   785.622933   869.352620
#
#           2006         2007         2008         2009         2010  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3  1146.694855  1137.949266  1510.482138  1706.976899  1800.870627
# 4   840.780713   870.586163   920.914005   841.320010   986.865004
#
#           2011
# 0          NaN
# 1          NaN
# 2          NaN
# 3  2021.634918
# 4  1090.565936
#
# [5 rows x 53 columns]

# %%
# pull out just the Canada data
dfc = df.loc[df['country'] == 'Canada']

# %%
dfc.head()
# Out:
#    country         1960         1961        1962        1963         1964  \
# 37  Canada  5630.629813  5605.111926  5791.12496  5966.04092  6468.926261
#
#           1965         1966         1967         1968      ...       \
# 37  6909.89938  7359.088188  7630.168528  8030.418434      ...
#
#             2002          2003          2004          2005          2006  \
# 37  16959.600791  17191.154186  17235.411783  17319.231245  16761.043703
#
#           2007          2008          2009          2010          2011
# 37  16847.8844  16449.953781  15119.764141  16153.787841  16405.707289
#
# [1 rows x 53 columns]

# %%
# drop country column
cols = [0]
dfc.drop(dfc.columns[cols], axis=1, inplace=True)
dfc.head()
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
#            1960         1961        1962        1963         1964        1965  \
# 37  5630.629813  5605.111926  5791.12496  5966.04092  6468.926261  6909.89938
#
#            1966         1967         1968         1969      ...       \
# 37  7359.088188  7630.168528  8030.418434  8532.908503      ...
#
#             2002          2003          2004          2005          2006  \
# 37  16959.600791  17191.154186  17235.411783  17319.231245  16761.043703
#
#           2007          2008          2009          2010          2011
# 37  16847.8844  16449.953781  15119.764141  16153.787841  16405.707289
#
# [1 rows x 52 columns]

# %%
# transpose it
dfc = dfc.T
dfc.head()
# Out:
#                37
# 1960  5630.629813
# 1961  5605.111926
# 1962  5791.124960
# 1963  5966.040920
# 1964  6468.926261

# %%
# rename the columns
dfc.index.name = 'year'
dfc.columns = ['value']
dfc.head()
# Out:
#             value
# year
# 1960  5630.629813
# 1961  5605.111926
# 1962  5791.124960
# 1963  5966.040920
# 1964  6468.926261

# %%
# drop if any value in the row has a nan
dfc.dropna(how='any', inplace = True);

# %%
# for plotting ease, make the year a column
dfc.reset_index(inplace = True)
dfc.head()
# Out:
#    year        value
# 0  1960  5630.629813
# 1  1961  5605.111926
# 2  1962  5791.124960
# 3  1963  5966.040920
# 4  1964  6468.926261

# %%
dfc.plot();

# %%
plt.plot(dfc['year'], dfc['value'])

plt.title('Electricity consumption, Canada')
plt.xlabel('Year')
plt.ylabel('per capita (kWh)')

plt.show()
