# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

% matplotlib inline

# %%
df = pd.read_csv('source_data/csv/aid.csv')

# %%
df.head()
# Out:
#   Government and civil society aid (% of total aid)  1967  1968  1969  1970  \
# 0                                         Australia   NaN   NaN   NaN   NaN
# 1                                           Austria   NaN   NaN   NaN   NaN
# 2                                           Belgium   NaN   NaN   NaN   NaN
# 3                                            Canada   NaN   NaN   NaN   NaN
# 4                                           Denmark   NaN   NaN   NaN   NaN
#
#        1971      1972       1973       1974       1975     ...       \
# 0       NaN  0.666504  19.008836  27.019805  14.420505     ...
# 1       NaN       NaN   0.314698   0.046315   2.311725     ...
# 2  1.053286  2.371998   7.938582  11.073059   3.029638     ...
# 3       NaN  3.784353   0.654057        NaN   2.117721     ...
# 4       NaN       NaN   9.420033   4.025995   2.421057     ...
#
#         2000       2001       2002       2003       2004       2005  \
# 0  21.557412  24.174104  21.843634  20.458464  30.109262  30.787457
# 1  19.025434  29.106754  17.938803  20.059257  14.467652  17.173874
# 2  14.639931  17.784906  17.756080  15.665696  13.367858  16.564940
# 3  22.438525  19.644220  21.036958  18.953973  24.483816  28.635660
# 4   5.308762  34.451171  17.409707  20.257581  14.538701  18.342189
#
#         2006       2007  2008  Unnamed: 43
# 0  36.129754  38.864047   NaN          NaN
# 1  21.432187  18.555068   NaN          NaN
# 2  19.434969  15.932946   NaN          NaN
# 3  29.856802  33.751780   NaN          NaN
# 4  16.372160  25.762540   NaN          NaN
#
# [5 rows x 44 columns]

# %%
# replace spaces with underscores and make lowercase
df.rename(columns=lambda x: x.strip().lower().replace(" ", "_"), inplace=True)

# %%
df.head()
# Out:
#   government_and_civil_society_aid_(%_of_total_aid)  1967  1968  1969  1970  \
# 0                                         Australia   NaN   NaN   NaN   NaN
# 1                                           Austria   NaN   NaN   NaN   NaN
# 2                                           Belgium   NaN   NaN   NaN   NaN
# 3                                            Canada   NaN   NaN   NaN   NaN
# 4                                           Denmark   NaN   NaN   NaN   NaN
#
#        1971      1972       1973       1974       1975     ...       \
# 0       NaN  0.666504  19.008836  27.019805  14.420505     ...
# 1       NaN       NaN   0.314698   0.046315   2.311725     ...
# 2  1.053286  2.371998   7.938582  11.073059   3.029638     ...
# 3       NaN  3.784353   0.654057        NaN   2.117721     ...
# 4       NaN       NaN   9.420033   4.025995   2.421057     ...
#
#         2000       2001       2002       2003       2004       2005  \
# 0  21.557412  24.174104  21.843634  20.458464  30.109262  30.787457
# 1  19.025434  29.106754  17.938803  20.059257  14.467652  17.173874
# 2  14.639931  17.784906  17.756080  15.665696  13.367858  16.564940
# 3  22.438525  19.644220  21.036958  18.953973  24.483816  28.635660
# 4   5.308762  34.451171  17.409707  20.257581  14.538701  18.342189
#
#         2006       2007  2008  unnamed:_43
# 0  36.129754  38.864047   NaN          NaN
# 1  21.432187  18.555068   NaN          NaN
# 2  19.434969  15.932946   NaN          NaN
# 3  29.856802  33.751780   NaN          NaN
# 4  16.372160  25.762540   NaN          NaN
#
# [5 rows x 44 columns]

# %%
# rename country column in place
df.rename(columns={'government_and_civil_society_aid_(%_of_total_aid)': 'country'}, inplace=True)
df.head()
# Out:
#      country  1967  1968  1969  1970      1971      1972       1973  \
# 0  Australia   NaN   NaN   NaN   NaN       NaN  0.666504  19.008836
# 1    Austria   NaN   NaN   NaN   NaN       NaN       NaN   0.314698
# 2    Belgium   NaN   NaN   NaN   NaN  1.053286  2.371998   7.938582
# 3     Canada   NaN   NaN   NaN   NaN       NaN  3.784353   0.654057
# 4    Denmark   NaN   NaN   NaN   NaN       NaN       NaN   9.420033
#
#         1974       1975     ...            2000       2001       2002  \
# 0  27.019805  14.420505     ...       21.557412  24.174104  21.843634
# 1   0.046315   2.311725     ...       19.025434  29.106754  17.938803
# 2  11.073059   3.029638     ...       14.639931  17.784906  17.756080
# 3        NaN   2.117721     ...       22.438525  19.644220  21.036958
# 4   4.025995   2.421057     ...        5.308762  34.451171  17.409707
#
#         2003       2004       2005       2006       2007  2008  unnamed:_43
# 0  20.458464  30.109262  30.787457  36.129754  38.864047   NaN          NaN
# 1  20.059257  14.467652  17.173874  21.432187  18.555068   NaN          NaN
# 2  15.665696  13.367858  16.564940  19.434969  15.932946   NaN          NaN
# 3  18.953973  24.483816  28.635660  29.856802  33.751780   NaN          NaN
# 4  20.257581  14.538701  18.342189  16.372160  25.762540   NaN          NaN
#
# [5 rows x 44 columns]

# %%
# pull out just the Canada data
dfc = df.loc[df['country'] == 'Canada']

# %%
dfc.head()
# Out:
#   country  1967  1968  1969  1970  1971      1972      1973  1974      1975  \
# 3  Canada   NaN   NaN   NaN   NaN   NaN  3.784353  0.654057   NaN  2.117721
#
#       ...            2000      2001       2002       2003       2004  \
# 3     ...       22.438525  19.64422  21.036958  18.953973  24.483816
#
#        2005       2006      2007  2008  unnamed:_43
# 3  28.63566  29.856802  33.75178   NaN          NaN
#
# [1 rows x 44 columns]

# %%
# drop country column
cols = [0]
dfc.drop(dfc.columns[cols], axis=1, inplace=True)
dfc.head()
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
#    1967  1968  1969  1970  1971      1972      1973  1974      1975     1976  \
# 3   NaN   NaN   NaN   NaN   NaN  3.784353  0.654057   NaN  2.117721  7.33672
#
#       ...            2000      2001       2002       2003       2004  \
# 3     ...       22.438525  19.64422  21.036958  18.953973  24.483816
#
#        2005       2006      2007  2008  unnamed:_43
# 3  28.63566  29.856802  33.75178   NaN          NaN
#
# [1 rows x 43 columns]

# %%
# transpose it
dfc = dfc.T
dfc.head()
# Out:
#        3
# 1967 NaN
# 1968 NaN
# 1969 NaN
# 1970 NaN
# 1971 NaN

# %%
# rename the columns
dfc.index.name = 'year'
dfc.columns = ['value']
dfc.head()
# Out:
#       value
# year
# 1967    NaN
# 1968    NaN
# 1969    NaN
# 1970    NaN
# 1971    NaN

# %%
# drop if any value in the row has a nan
dfc.dropna(how='any', inplace = True);

# %%
# for plotting ease, make the year a column
dfc.reset_index(inplace = True)
dfc.head()
# Out:
#    year     value
# 0  1972  3.784353
# 1  1973  0.654057
# 2  1975  2.117721
# 3  1976  7.336720
# 4  1977  3.749176

# %%
dfc.plot();

# %%
plt.plot(dfc['year'], dfc['value'])

plt.title('Government and civil society aid, Canada')
plt.xlabel('Year')
plt.ylabel('% of total aid')

plt.show()
